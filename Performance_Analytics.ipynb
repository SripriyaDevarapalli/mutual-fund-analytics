# %% [markdown]
# # Mutual Fund Performance Analytics
#
# Author: Devarapalli Sripriya Reddy
#
# Objective:
# Evaluate mutual fund performance using CAGR, Sharpe Ratio, Sortino Ratio, Alpha, Beta, Maximum Drawdown, and Benchmark Comparison.

# %% [markdown]
# # CAGR Analysis

# %%
import pandas as pd

cagr = pd.read_csv(
    "reports/cagr_report.csv"
)

cagr.head()
# Out:
#    amfi_code      CAGR
# 0     100016  0.026352
# 1     100025  0.044551
# 2     100033  0.300997
# 3     101206  0.235205
# 4     101207  0.079331

# %% [markdown]
# # Sharpe Ratio and Sortino Ratio

# %%
risk = pd.read_csv(
    "reports/risk_metrics.csv"
)

risk.sort_values(
    "Sharpe",
    ascending=False
).head(10)
# Out:
#     amfi_code    Sharpe   Sortino
# 34     148567  1.448291  2.385644
# 30     120843  1.306744  2.364320
# 36     148569  1.234930  2.146914
# 19     119551  1.208267  2.140267
# 25     120505  1.180101  2.029353
# 38     149323  1.132122  1.875101
# 2      100033  1.093699  1.829134
# 9      118632  1.081659  1.850133
# 3      101206  1.027213  1.799563
# 24     120504  1.026524  1.805294

# %% [markdown]
# # Alpha and Beta Analysis

# %%
alpha = pd.read_csv(
    "reports/alpha_beta.csv"
)

alpha.head()
# Out:
#    amfi_code     Alpha      Beta
# 0     100016  0.035273  0.000023
# 1     100025  0.043864 -0.000056
# 2     100033  0.268942  0.000175
# 3     101206  0.212161  0.000137
# 4     101207  0.104643  0.000128

# %% [markdown]
# # Maximum Drawdown Analysis

# %%
mdd = pd.read_csv(
    "reports/max_drawdown.csv"
)

mdd.head()
# Out:
#    amfi_code  max_drawdown
# 0     100016     -0.247344
# 1     100025     -0.043083
# 2     100033     -0.162172
# 3     101206     -0.112916
# 4     101207     -0.354469

# %% [markdown]
# # Composite Fund Scorecard

# %%
score = pd.read_csv(
    "reports/fund_scorecard.csv"
)

score[
[
"scheme_name",
"score"
]
].head(10)
# Out:
#                                          scheme_name    score
# 0         SBI Small Cap Fund - Regular Plan - Growth  82.7500
# 1           ICICI Pru Midcap Fund - Regular - Growth  81.6250
# 2              DSP Small Cap Fund - Regular - Growth  77.3125
# 3  HDFC Mid-Cap Opportunities Fund - Regular - Gr...  74.8750
# 4             Kotak Flexicap Fund - Regular - Growth  74.6250
# 5                Axis Midcap Fund - Regular - Growth  69.6250
# 6      Mirae Asset Large Cap Fund - Regular - Growth  68.6250
# 7                 DSP Midcap Fund - Regular - Growth  68.3750
# 8          ICICI Pru Bluechip Fund - Direct - Growth  62.8750
# 9      Mirae Asset Tax Saver Fund - Regular - Growth  62.0625

# %% [markdown]
# # Benchmark Comparison

# %%
from IPython.display import Image

Image(
    "reports/benchmark_comparison.png"
)

# %% [markdown]
# # Performance Analytics Insights
#
# 1. Small-cap and mid-cap funds achieved the highest composite scores.
#
# 2. Funds with higher Sharpe Ratios generated better risk-adjusted returns.
#
# 3. Positive Alpha indicates manager skill beyond benchmark performance.
#
# 4. Lower Maximum Drawdown suggests stronger downside protection.
#
# 5. Benchmark comparison shows several funds outperforming broad market indices.
#
# 6. Composite scorecard combines returns, risk, alpha, expenses, and drawdown.
#
# 7. Risk-adjusted performance metrics provide better fund evaluation than returns alone.

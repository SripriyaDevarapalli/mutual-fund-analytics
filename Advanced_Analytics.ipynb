# %%
Advanced_Analytics

# %% [markdown]
# # Mutual Fund Advanced Analytics
#
# Author: Sripriya
#
# Objective:
# Perform advanced risk analytics, investor analytics, portfolio concentration analysis, and fund recommendations using mutual fund datasets.

# %% [markdown]
# # Historical VaR and CVaR Analysis

# %%
import pandas as pd

var_df = pd.read_csv(
    "reports/var_cvar_report.csv"
)

var_df.head()
# Out:
#    amfi_code    VaR_95   CVaR_95
# 0     100016 -0.014364 -0.018060
# 1     100025 -0.003793 -0.004994
# 2     100033 -0.019034 -0.023456
# 3     101206 -0.013282 -0.017439
# 4     101207 -0.026021 -0.032459

# %% [markdown]
# # Rolling 90-Day Sharpe Ratio

# %%
from IPython.display import Image

Image(
    "reports/rolling_sharpe_chart.png"
)

# %% [markdown]
# # Investor Cohort Analysis

# %%
cohort = pd.read_csv(
    "reports/cohort_analysis.csv"
)

cohort
# Out:
#    cohort     avg_amount  total_invested
# 0    2024  107422.541832      3491125187
# 1    2025  109158.577061        30455243

# %% [markdown]
# # SIP Continuity Analysis

# %%
sip = pd.read_csv(
    "reports/sip_continuity.csv"
)

sip.head()
# Out:
#   investor_id    avg_gap   status
# 0   INV000004  85.400000  At-Risk
# 1   INV000008  70.400000  At-Risk
# 2   INV000010  64.800000  At-Risk
# 3   INV000011  40.166667  At-Risk
# 4   INV000012  57.000000  At-Risk

# %% [markdown]
# # Sector HHI Concentration Analysis

# %%
hhi = pd.read_csv(
    "reports/sector_hhi.csv"
)

hhi.head()
# Out:
#    amfi_code       HHI
# 0     119551  0.118716
# 1     119552  0.108011
# 2     119598  0.107349
# 3     119599  0.174751
# 4     100016  0.139534

# %% [markdown]
# # Advanced Business Insights
#
# 1. Historical VaR and CVaR analysis reveals meaningful differences in downside risk across mutual fund schemes.
#
# 2. Funds with larger negative VaR values are more vulnerable during periods of market stress and volatility.
#
# 3. Investor cohort analysis shows that the 2024 cohort contributes the majority of invested capital, indicating strong retail participation.
#
# 4. SIP continuity analysis identifies investors with average contribution gaps above 35 days as at-risk investors.
#
# 5. Rolling Sharpe ratios demonstrate that risk-adjusted performance changes across market cycles and should be monitored periodically.
#
# 6. Sector HHI analysis highlights concentration risk among equity funds and helps distinguish diversified versus concentrated portfolios.
#
# 7. Fund recommendations based on Sharpe ratios can improve risk-adjusted portfolio selection for investors.
